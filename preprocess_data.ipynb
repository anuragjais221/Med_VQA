# %%
### install dependencies

# %%
# ! pip install ruamel_yaml
# ! pip install pandas
# ! pip install easydict
# ! pip install torch
# ! pip install torchvision
# ! pip install spacy
# Out:
# Requirement already satisfied: ruamel_yaml in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (0.17.24)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from ruamel_yaml) (0.2.7)
# Requirement already satisfied: pandas in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: easydict in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (1.10)
# Requirement already satisfied: torch in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: filelock in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch) (2.0.0)
# Requirement already satisfied: setuptools in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.7.2)
# Requirement already satisfied: wheel in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.40.0)
# Requirement already satisfied: cmake in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from triton==2.0.0->torch) (3.26.3)
# Requirement already satisfied: lit in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: torchvision in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (0.15.2)
# Requirement already satisfied: numpy in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torchvision) (2.30.0)
# Requirement already satisfied: torch==2.0.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: filelock in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: setuptools in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (67.7.2)
# Requirement already satisfied: wheel in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (0.40.0)
# Requirement already satisfied: cmake in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.26.3)
# Requirement already satisfied: lit in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from requests->torchvision) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from jinja2->torch==2.0.1->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Requirement already satisfied: spacy in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (1.10.7)
# Requirement already satisfied: jinja2 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/anurag/anaconda3/envs/med_vqa/lib/python3.11/site-packages (from jinja2->spacy) (2.1.2)

# %%
PROJ_DIR='/home/anurag/Med_VQA/'
CNF_PATH='/home/anurag/Med_VQA/default.yaml'

# %%
import os
import pandas as pd
from typing import Union, Optional, Any, List
from pathlib import Path
from easydict import EasyDict as edict
from ruamel.yaml import YAML, yaml_object
import pickle
import json
# from mvqag import PROJ_DIR

# %%
yaml = YAML(typ='safe', pure=True)
yaml.default_flow_style = False
yaml.indent(mapping=2, sequence=4, offset=2)

# %%
@yaml_object(yaml)
class JoinPath:
    """Custom tag `!join` loader class to join strings for yaml file."""

    yaml_tag = u'!joinpath'

    def __init__(self, joined_string):
        self.joined_string = joined_string

    @classmethod
    def to_yaml(cls, representer, node):
        return representer.represent_scalar(cls.yaml_tag,
                                            u'{.joined_string}'.format(node))

    @classmethod
    def from_yaml(cls, constructor, node):
        seq = constructor.construct_sequence(node)
        fullpath = Path(os.path.join(*[str(i) for i in seq])).resolve()
        return str(fullpath)

# %%
@yaml_object(yaml)
class ProjDirSetter:
    """Custom tag `!projdir` loader class for yaml file."""

    yaml_tag = u'!projdir'

    def __init__(self, path):
        self.path = path

    @classmethod
    def to_yaml(cls, representer, node):
        return representer.represent_scalar(cls.yaml_tag,
                                            u'{.path}'.format(node))

    @classmethod
    def from_yaml(cls, constructor, node):
        return str(PROJ_DIR)

# %%
def load_yaml(path: Union[str, Path], pure: bool = False) -> dict:
    """config.yaml file loader.
    This function converts the config.yaml file to `dict` object.
    Args:
        path: .yaml configuration filepath
        pure: If True, just load the .yaml without converting to EasyDict
            and exclude extra info.
    Returns:
        `dict` object containing configuration parameters.
    Example:
        .. code-block:: python
            config = load_yaml("../config.yaml")
            print(config["project_name"])
    """

    path = str(Path(path).absolute().resolve())
    # * Load config file
    with open(path) as file:
        config = yaml.load(file)

    if pure == False:  # Add extra features
        # Convert dict to easydict
        config = edict(config)
    return config

# %%
# ----------------------------------------> .txt and .csv :
def load_qa_file(
    qa_filepath: Union[Path, str], columns: Optional[List[str]] = None
) -> pd.DataFrame:
    """Load questions answers `.txt` and `.csv` files.

    Args:
        qa_filepath: full path to the file
        columns: if file is `.txt`, then enter the columns names.

    Returns:
        pandas dataframe.
    """

    qa_filepath = Path(qa_filepath)
    # print('qa_filepath',qa_filepath)
    if qa_filepath.suffix == ".txt":  # For raw data files
        if columns == None:
            raise AttributeError(
                "columns=<list of names of colunms> is required for .txt files."
            )
        df = pd.read_table(qa_filepath, delimiter="|", header=None)
        assert df.shape[1] == len(
            columns
        ), f"[Error @ `load_qa_file`] Number of columns in dataframe are {df.shape[1]} but given columns list has {len(columns)} names."
        df.columns = columns

    elif qa_filepath.suffix == ".csv":  # if file is .csv
        df = pd.read_csv(qa_filepath)
    else:
        raise ValueError(
            "[Error @ `load_qa_file`] Problem loading .txt qa_filepath")
    return df

# %%
# ----------------------------------------> JSON :
def load_json(path: Union[str, Path], pure: bool = False) -> edict:
    """Load .json file from given path

    Args:
        path: Path/to/the/file.json
        pure: If True, return the loaded .json content as it is.
            If False, convert it to EasyDict format
    """
    import json
    with open(path) as f:
        _data = json.load(f)
        if pure:
            return _data
        return edict(_data)


def save_json(object: Any, path: Union[str, Path]) -> None:
    """Save .json file to given path"""
    import json
    path = Path(path).resolve()
    path.parent.mkdir(parents=True, exist_ok=True)
    with open(str(path), 'w') as f:
        json.dump(object, f)

# %%
CNF = load_yaml(CNF_PATH)

# %%
CNF
# Out:
# {'seed': 1234,
#  'n_workers': 4,
#  'project_name': 'Med_VQA',
#  'clef_cols': {'default': ['ID', 'Q', 'A'],
#   'default18': ['S.No', 'ID', 'Q', 'A'],
#   'test19': ['ID', 'Task', 'Q', 'A'],
#   'test20': ['ID', 'Q'],
#   'test20A': ['ID', 'Q', 'A'],
#   'test21': ['ID', 'Q']},
#  'data': {'augment': True,
#   'aug_type': 'manual',
#   'normalize': True,
#   'mean': [0.485, 0.456, 0.406],
#   'std': [0.229, 0.224, 0.225],
#   'QG': False,
#   'n_classes': 330},
#  'model': {'qnet_name': 'GRU',
#   'vnet_name': 'VGG16',
#   'vdp': 0.2,
#   'qdp': 0.2,
#   'inp_size': 224,
#   'max_len': 12,
#   'emb_dim': 128,
#   'use_SAN': False},
#  'loss': {'fn': 'CrossEntropy', 'smoothing': 0.0, 'wts': 'None'},
#  'optm': {'name': 'SGD',
#   'lr': 0.001,
#   'wd': 0.0005,
#   'mom': 0.9,
#   'nesterov': False,
#   'betas': [0.9, 0.99],
#   'amsgrad': True},
#  'train': {'bs': 32,
#   'n_epochs': 60,
#   'swa': False,
#   'vqa_mixup': 0.0,
#   'max_train_iters': -1,
#   'max_val_iters': -1},
#  'test': {'bs': 1},
#  'task_keywords': {'abnormality': ['normal',
#    'abnormal',
#    'abnormality',
#    'abnormalities',
#    'alarming',
#    'wrong'],
#   'modality': ['x-ray',
#    'mri',
#    'ultrasound',
#    'ct',
#    'mammograph',
#    'pet',
#    'nuclear_medicine_image',
#    'angiogram',
#    'modality',
#    'kind',
#    'gastrointestinal'],
#   'fine_modality': ['noncontrast',
#    'contrast',
#    't1',
#    't2',
#    'flair',
#    't2_weighted',
#    't1_weighted',
#    'gi_contrast',
#    'iv_contrast',
#    'stir',
#    'dwi',
#    'barium_swallow',
#    'fiesta',
#    'angiography',
#    'venography',
#    'pdw'],
#   'organ': ['part', 'organ'],
#   'plane': ['plane']},
#  'paths': {'proj_dir': '/home/anurag/Med_VQA/',
#   'data_dir': '/home/anurag/Med_VQA/data',
#   'logs_dir': '/home/anurag/Med_VQA/logs',
#   'tests_dir': '/home/anurag/Med_VQA/tests',
#   'chkpts_dir': '/home/anurag/Med_VQA/checkpoints',
#   'notebooks_dir': '/home/anurag/Med_VQA/notebooks',
#   'raw_dir': '/home/anurag/Med_VQA/data/raw',
#   'clef_dir': '/home/anurag/Med_VQA/data/raw/ImageCLEF',
#   'slake_dir': '/home/anurag/Med_VQA/data/raw/Slake1.0',
#   'sysu_dir': '/home/anurag/Med_VQA/data/raw/SYSU',
#   'vqa_rad_dir': '/home/anurag/Med_VQA/data/raw/VQA_RAD',
#   'clef_19_train_imgs': '/home/anurag/Med_VQA/data/raw/ImageCLEF/train_2019/Train_images',
#   'clef_19_train_qa': '/home/anurag/Med_VQA/data/raw/ImageCLEF/train_2019/All_QA_Pairs_train.txt',
#   'clef_19_val_imgs': '/home/anurag/Med_VQA/data/raw/ImageCLEF/val_2019/Val_images',
#   'clef_19_val_qa': '/home/anurag/Med_VQA/data/raw/ImageCLEF/val_2019/All_QA_Pairs_val.txt',
#   'clef_19_test_imgs': '/home/anurag/Med_VQA/data/raw/ImageCLEF/test_2019/VQAMed2019_Test_Images',
#   'clef_19_test_qa': '/home/anurag/Med_VQA/data/raw/ImageCLEF/test_2019/VQAMed2019_Test_Questions_w_Ref_Answers.txt',
#   'clef_20_train_imgs': '/home/anurag/Med_VQA/data/raw/ImageCLEF/train_2020/VQAnswering_2020_Train_images',
#   'clef_20_train_qa': '/home/anurag/Med_VQA/data/raw/ImageCLEF/train_2020/VQAnswering_2020_Train_QA_pairs.txt',
#   'clef_20_val_imgs': '/home/anurag/Med_VQA/data/raw/ImageCLEF/val_2020/VQAnswering_2020_Val_images',
#   'clef_20_val_qa': '/home/anurag/Med_VQA/data/raw/ImageCLEF/val_2020/VQAnswering_2020_Val_QA_Pairs.txt',
#   'clef_20_test_imgs': '/home/anurag/Med_VQA/data/raw/ImageCLEF/test_2020/Task1-2020-VQAnswering-Test-Images',
#   'clef_20_test_qa': '/home/anurag/Med_VQA/data/raw/ImageCLEF/test_2020/Task1-2020-VQAnswering-Test-Questions.txt',
#   'clef_20_test_qa_sysu': '/home/anurag/Med_VQA/data/raw/ImageCLEF/test_2020/Task1-2020-VQAnswering-Test-Questions-Answers.csv',
#   'clef_21_val_imgs': '/home/anurag/Med_VQA/data/raw/ImageCLEF/val_2021/ImageCLEF-2021-VQA-Med-New-Validation-Images',
#   'clef_21_val_qa': '/home/anurag/Med_VQA/data/raw/ImageCLEF/val_2021/VQA-Med-2021-VQAnswering-Task1-New-ValidationSet.txt',
#   'clef_21_test_imgs': '/home/anurag/Med_VQA/data/raw/ImageCLEF/test_2021/Task1-VQA-2021-TestSet-Images',
#   'clef_21_test_qa': '/home/anurag/Med_VQA/data/raw/ImageCLEF/test_2021/Task1-VQA-2021-TestSet-Questions.txt',
#   'clef_sysu_ltoc_filepath': '/home/anurag/Med_VQA/data/raw/SYSU/id2disease.json',
#   'clef_sysu_train_imgs': '/home/anurag/Med_VQA/data/raw/SYSU/train/images',
#   'clef_sysu_train_qa': '/home/anurag/Med_VQA/data/raw/SYSU/train/Med_LT_train.txt',
#   'clef_sysu_val_imgs': '/home/anurag/Med_VQA/data/raw/SYSU/val/images',
#   'clef_sysu_val_qa': '/home/anurag/Med_VQA/data/raw/SYSU/val/Med_LT_val.txt'}}

# %%
import torch
import torchvision.transforms as T
import math
from typing import Union, Dict, List, Any, Optional, Callable
from pandas import DataFrame
from PIL import Image
import re
import pandas as pd
from typing import Set, List, Dict
from collections import defaultdict
from collections import OrderedDict
from pathlib import Path
from spacy.lang.en import English
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
nlp = English()

# %%
# ============================= FUNCTIONS ==============================
def get_device():
    """Get torch device instance and available GPU IDs"""
    from torch.cuda import device_count
    from torch import device
    print('device_count',device_count())
    cuda_ids = [0] if device_count() == 1 else list(range(device_count()))
    
    return device(f"cuda:{cuda_ids[0]}"), cuda_ids

# %%
torch.manual_seed(CNF.seed)
torch.cuda.manual_seed(CNF.seed)
torch.cuda.manual_seed_all(CNF.seed)

# %%
class Tokenizer:
    def __init__(self, vocab: Set[str], max_len: int) -> None:
        self.pad = '<pad>'
        self.bos = '<bos>'
        self.eos = '<eos>'
        self.unk = '<unk>'
        self.special_tokens = [self.pad, self.bos, self.eos, self.unk]
        self.vocab = self.special_tokens + sorted(list(vocab))
        self.vocab = {w: i for i, w in enumerate(self.vocab)}
        self.vocab = defaultdict(lambda: self.vocab[self.unk], self.vocab)
        self.idx_to_word = {v: k for k, v in self.vocab.items()}
        self.max_len = max_len
        self.vocab_dim = len(self.vocab)

    def encode(self, sent: str) -> Dict[str, list]:
        sent = sent.lower()
        tokens = [
            self.vocab[str(word)] for word in nlp.tokenizer(sent)
        ]
        tokens = tokens[:self.max_len - 2]
        # Add sentence begining and end
        tokens = [self.vocab[self.bos]] + tokens + [self.vocab[self.eos]]
        total_tokens = len(tokens)
        if total_tokens != self.max_len:
            rem = self.max_len - total_tokens
            tokens += [self.vocab[self.pad]]*rem
        return {
            'input_ids': tokens
        }

    def decode(self, tokens: List[int]) -> str:
        tokens = [self.idx_to_word[t] for t in tokens]
        decoded = [
            token
            for token in tokens
            if (token != self.vocab.pad) and
               (token != self.vocab.bos) and
               (token != self.vocab.eos)
        ]
        return ' '.join(decoded)

    @classmethod
    def from_list(cls, unique_ques_list: List[str], max_len: int):
        vocab = set([
            str(word) for sent in unique_ques_list
            for word in nlp.tokenizer(sent.lower())
        ])
        return cls(vocab, max_len=max_len)

# %%
class DataLoaders:
    def __init__(self,
                 trainloader: Union[DataLoader, None] = None,
                 valloader: Union[DataLoader, None] = None,
                 testloader: Union[DataLoader, None] = None,
                 n_workers: int = 4) -> None:
        if trainloader:
            self.train_bs = trainloader.batch_size
            self.trainset = trainloader.dataset
            self.trainloader = trainloader
        if valloader:
            self.val_bs = valloader.batch_size
            self.valset = valloader.dataset
            self.valloader = valloader
        if testloader:
            self.test_bs = testloader.batch_size
            self.testset = testloader.dataset
            self.testloader = testloader
        self.n_workers = n_workers

    @classmethod
    def from_dataset(cls,
                     trainset: Optional[Dataset] = None,
                     train_bs: Optional[int] = None,
                     valset: Optional[Dataset] = None,
                     val_bs: Optional[int] = None,
                     testset: Optional[Dataset] = None,
                     test_bs: Optional[int] = None,
                     n_workers: Optional[int] = 4,
                     collate_fn: Optional[Callable] = None
                     ) -> Dict[str, DataLoader]:
        """Create dataloaders from dataset classes

        Args:
            #TODO
        """
        if trainset == valset == testset == None:
            raise ValueError("At least one set is required")
        trainloader, valloader, testloader = None, None, None
        trainset, train_bs = trainset, train_bs
        valset, val_bs = valset, val_bs
        testset, test_bs = testset, test_bs
        if trainset is not None:
            trainloader = DataLoader(
                dataset=trainset,
                batch_size=train_bs,
                shuffle=True,
                num_workers=n_workers,
                collate_fn=collate_fn
            )
        if valset is not None:
            valloader = DataLoader(
                dataset=valset,
                batch_size=val_bs,
                shuffle=False,
                num_workers=n_workers,
                collate_fn=collate_fn
            )
        if testset is not None:
            testloader = DataLoader(
                dataset=testset,
                batch_size=test_bs,
                shuffle=False,
                num_workers=n_workers,
                collate_fn=collate_fn
            )
        return cls(
            trainloader=trainloader,
            valloader=valloader,
            testloader=testloader,
            n_workers=n_workers
        )

    def collate_fn(self):
        return None

    @property
    def n_train_batches(self) -> int:
        if self.trainset is not None:
            return math.ceil(len(self.trainset) / self.train_bs)

    @property
    def n_val_batches(self) -> Union[None, int]:
        if self.valset is not None:
            return math.ceil(len(self.valset) / self.val_bs)

    @property
    def n_test_batches(self) -> Union[None, int]:
        if self.testset is not None:
            return math.ceil(len(self.testset) / self.test_bs)

    @classmethod
    def from_dicts(cls,
                   train_dict: Dict[str, Any],
                   val_dict: Optional[Dict[str, Any]] = None,
                   test_dict: Optional[Dict[str, Any]] = None):
        valset, val_bs = val_dict['ds'], val_dict['bs']
        testset, test_bs = test_dict['ds'], test_dict['bs']
        return cls(trainset=train_dict['ds'],  # DataSet
                   train_bs=train_dict['bs'],  # BatchSize
                   valset=valset,
                   val_bs=val_bs,
                   testset=testset,
                   test_bs=test_bs
                   )

# %%
# ============================= CLASSES ==============================
class VQADataset(Dataset):
    def __init__(self,
                 df: DataFrame,
                 img_tfms: T.Compose,
                 classes: Union[None, List[str]],
                 tokenizer: Union[None, Callable] = None) -> None:
        """PyTorch Dataset abstract class wrapper

        Args:
            #TODO
        """
        super().__init__()

        self.df = df
        self.img_tfms = img_tfms
        self.classes = classes
        if self.classes is not None:
            self.n_classes = len(self.classes)
        self.tokenizer = tokenizer

    def __len__(self) -> int:
        return self.df.shape[0]

    def __getitem__(self, idx) -> Dict[str, torch.Tensor]:
        row = self.df.iloc[idx]

        # Visual
        img = Image.open(row.PATH).convert('RGB')
        if self.img_tfms is not None:
            img = self.img_tfms(img)

        # Question
        if self.tokenizer is None:
            question = None
        else:
            question = self.tokenizer.encode(row.Q)
            question = {
                k: torch.tensor(v).unsqueeze(0) for k, v in question.items()
            }

        # Answer
        target = torch.tensor(self.ctol(row.A))

        return {
            'inputs': {'V': img, 'Q': question},
            'target': target,
            'info': row
        }

    def ctol(self, c) -> int:
        return self.classes.index(c)

    def ltoc(self, l) -> str:
        return self.classes[l]

    @property
    def cls_wts(self) -> torch.Tensor:
        """Class balancing weights for balanced training"""
        n_samples = [None]*self.n_classes
        for cls, count in self.df.A.value_counts().to_dict().items():
            if self.classes is not None:
                label = self.ctol[cls]
            else: 
                label = cls
            n_samples[label] = count
        return sum(n_samples) / torch.tensor(n_samples)  # Class weights

# %%
def vqa_collate_fn(batch):
    collated = {
        'inputs': {
            'V': [],  # Image
            'Q': {'input_ids': []},  # Question
        },
        'target': []  # Answers
    }
    # Images
    for sample in batch:
        collated['inputs']['V'].append(sample['inputs']['V'].unsqueeze(0))
    collated['inputs']['V'] = torch.cat(collated['inputs']['V'])
    # Questions
    if batch[0]['inputs']['Q'] is None:
        collated['inputs']['Q'] = None
    else:
        for sample in batch:
            for k, v in sample['inputs']['Q'].items():
                collated['inputs']['Q'][k].append(v)
        collated['inputs']['Q'] = {
            k: torch.cat(v) for k, v in collated['inputs']['Q'].items()
        }

    # Answers
    for sample in batch:
        collated['target'].append(sample['target'].unsqueeze(0))
    collated['target'] = torch.cat(collated['target'])
    # Info
    collated['info'] = [sample['info'] for sample in batch]
    return collated

# %%
def match_task(question: str, keywords: list):
    """Match question words with the keywords.
    Return True and the matched word if at least one word is matched.
    """
    for word in question.split(" "):
        for kw in keywords:
            if word == kw:
                return word
    return ""

# %%
class PrepareCLEF2020DataWithQ:
    def __init__(self, CNF) -> None:
        self.n_classes = CNF.data.n_classes
        self.QG = CNF.data.QG

        # TRAINING DATA
        # This is the main dataset for training
        train20_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_20_train_qa,
            imgs_path=CNF.paths.clef_20_train_imgs,
            is_main_df=True
        )
        
        print('train20_df',train20_df.shape)
        # Get categorical abnormality classes
        self.classes = train20_df.A.unique().tolist()
        print('len classes',len(self.classes))
        # if self.n_classes == 330:
        #     if 'no' in self.classes:
        #         self.classes.remove('no')
        #     if 'yes' in self.classes:
        #         self.classes.remove('yes')
        self.classes = sorted(self.classes)
        print('classes',self.classes)
        print('len',len(self.classes))
        # assert len(self.classes) == self.n_classes
        # Remove yes/no classes from train20_df
        # train20_df = pd.DataFrame([
        #     row for row in train20_df.itertuples() if row.A in self.classes
        # ]).drop("Index", axis=1)

        
        # Filter abnormality data from other ImageCLEF datasets
        # print(type(train20_df))
        # display(train20_df)
        train19_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_19_train_qa,
            imgs_path=CNF.paths.clef_19_train_imgs
        )
        val19_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_19_val_qa,
            imgs_path=CNF.paths.clef_19_val_imgs
        )
        print('train19_df',train19_df.shape)
        print('val19_df',val19_df.shape)
        test19_df = self._make_dataframe(
            columns=CNF.clef_cols.test19,
            qa_path=CNF.paths.clef_19_test_qa,
            imgs_path=CNF.paths.clef_19_test_imgs
        )
        print('test19_df',test19_df.shape)
        # display(test19_df)
        # print('test19_df',test19_df)
        
        test19_df = test19_df.drop('Task', axis=1)
        training_dfs = [train19_df, val19_df, test19_df, train20_df]
        self.train_df = pd.concat(
            training_dfs, ignore_index=True
        ).reset_index(drop=True)

        print('self.train_df',self.train_df.shape)
        answer_freq = self._count_answer_freq(self.train_df)
        print('answer_freq',answer_freq)
        self.classes = self._get_most_frequent_classes(answer_freq, 1)
        self.train_df['labels'] = self.train_df['A'].apply(lambda x : self.classes[x] if x in self.classes else self.classes['UNKNOWN'])

        self.val_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_20_val_qa,
            imgs_path=CNF.paths.clef_20_val_imgs
        )



        self.val_df['labels'] = self.val_df['A'].apply(lambda x : self.classes[x] if x in self.classes else self.classes['UNKNOWN'])
        print('self.val_df',self.val_df.shape)

        self.test_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_21_val_qa,
            imgs_path=CNF.paths.clef_21_val_imgs
        )

        print('self.test_df',self.test_df.shape)

        # display(self.train_df)
        # Augmentation
        self.train_tfms = T.Compose([
            T.Resize(size=(CNF.model.inp_size + 8, CNF.model.inp_size + 8)),
            # T.AutoAugment(),
            T.RandomCrop(size=(CNF.model.inp_size, CNF.model.inp_size)),
            T.RandomHorizontalFlip(),
            T.ToTensor(),
            T.Normalize(
                mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
            )
        ])
        self.val_tfms = T.Compose([
            T.Resize(size=(CNF.model.inp_size, CNF.model.inp_size)),
            T.ToTensor(),
            T.Normalize(
                mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
            )
        ])
        # Generate new questions for training dataset
        if CNF.data.QG:
            print(f"Before QG: # training samples = {self.train_df.shape[0]}")
            self.train_df = self._generate_questions(self.train_df,
                                                     CNF.task_keywords)
            print(f"After QG: # training samples = {self.train_df.shape[0]}")
        self.tokenizer = Tokenizer.from_list(
            self.train_df.Q.unique().tolist(),
            max_len=CNF.model.max_len
        )
        # Make dataset classes
        self.trainset = VQADataset(
            self.train_df, self.train_tfms, self.classes, self.tokenizer
        )
        self.valset = VQADataset(
            self.val_df, self.val_tfms, self.classes, self.tokenizer
        )
        # Make dataloaders
        self.dls = DataLoaders.from_dataset(
            trainset=self.trainset,
            train_bs=CNF.train.bs,
            valset=self.valset,
            val_bs=1,
            collate_fn=vqa_collate_fn
        )

    def _make_dataframe(self,
                        columns,
                        qa_path,
                        imgs_path,
                        is_main_df=False):
        df = load_qa_file(qa_filepath=qa_path, columns=columns)
        df['PATH'] = df.ID.apply(lambda x: f"{imgs_path}/{x}.jpg")
        if not is_main_df:
            df = pd.DataFrame([
                row for row in df.itertuples() if row.A in self.classes
            ]).drop("Index", axis=1)
        return df
    
    def _count_answer_freq(self,train_df: pd.DataFrame):
        '''
        count the frequence of each unique answer on the dataset
        '''
        all_answers = train_df['A'].values
        answer_freq_dict = defaultdict(int)
        for answer in all_answers:
            answer_freq_dict[answer] += 1
        answer_freq_dict_sort = dict(sorted(answer_freq_dict.items(), key=lambda x: x[1], reverse=True))

        return answer_freq_dict_sort
    
    def _get_most_frequent_classes(self,answer_freq_dict, threshold=1):
        print('threshold',threshold)
        final_classes = defaultdict(int)
        index = 0

        for answer,ans_freq in answer_freq_dict.items():

            if ans_freq >= threshold:
                final_classes[answer]= index         
            else:
                final_classes['UNKNOWN'] = index
                break
            index += 1  
        final_classes['UNKNOWN'] = index
        with open('answer_classes_2020_subset19.json', 'w') as fp:
            json.dump(final_classes, fp)
        return final_classes

    # def _generate_questions(
    #     self,
    #     train_df: pd.DataFrame,
    #     task_keywords: Dict[str, List[str]]
    # ) -> pd.DataFrame:
    #     new_train_df = generate_new_questions_dataframe(
    #         train_df, task_keywords
    #     )
    #     new_train_df = new_train_df[new_train_df.Task == 'abnormality']
    #     new_train_df = new_train_df[new_train_df.SubTask == 'categorical']
    #     return new_train_df

    def check(self):
        print(f"Data augmentation:\n\t{self.train_tfms}", end='')
        print(f"\n\t{self.val_tfms}")
        print(f"# training samples = {self.train_df.shape}")
        print(f"# validation samples = {self.val_df.shape}")
        train_pickle_name='train20_subset19_df'
        self.train_df.to_pickle('/home/anurag/Med_VQA/train_dataset_pickle/'+train_pickle_name+'.pkl')
        self.train_df.to_csv('train20_subset19.csv')
        valid_pickle_name = 'val20_df'
        self.val_df.to_pickle('/home/anurag/Med_VQA/valid_dataset_pickle/'+valid_pickle_name+'.pkl')
        self.val_df.to_csv('val20.csv')
        test_pickle_name = 'test_val21_df'
        self.test_df.to_pickle('/home/anurag/Med_VQA/test_dataset_pickle/'+test_pickle_name+'.pkl')
        self.test_df.to_csv('test_val21.csv')
        print('saved')
        if self.n_classes == 330:
            assert self.train_df.shape == (4963, 5)
            assert self.val_df.shape == (472, 5)
        elif self.n_classes == 332:
            if self.QG:
                assert self.train_df.shape == (39704, 6)
            else:
                assert self.train_df.shape == (6583, 4)
            assert self.val_df.shape == (500, 4)
        else:
            _errmsg = f"check not added for classes = {self.n_classes}"
            raise NotImplementedError(_errmsg)
        assert self.train_df.A.nunique() <= self.n_classes
        assert self.val_df.A.nunique() <= self.n_classes
        assert len(self.trainset) == self.train_df.shape[0]
        assert len(self.valset) == self.val_df.shape[0]

        batch = next(iter(self.dls.trainloader))
        print(f"data batch:")
        print(f"\tV = {batch['inputs']['V'].shape}")
        print(f"\tQ = {batch['inputs']['Q']['input_ids'].shape}")
        print(f"\tA = {batch['target'].shape}")
        print("data check: [green]PASSED[/green]")

# %%
dm = PrepareCLEF2020DataWithQ(CNF)
# Out:
# train20_df (4000, 4)
# len classes 332
# classes ['abdominal abscess', 'abdominal aortic aneurysm', 'abdominal compartment syndrome', 'aberrant right subclavian artery (arsa)', 'achalasia', 'achilles tendon rupture', 'acl injury', 'acute appendicitis', 'acute calculous cholecystitis', 'acute mesenteric ischemia', 'acute pediatric osteomyelitis', 'acute pyelonephritis', 'adenocarcinoma of the gastroesophageal junction', 'adenocarcinoma of the lung', 'adenomyomatosis', 'adenomyosis', 'adpkd -autosomal dominant polycystic kidney disease', 'adrenal adenoma', 'adrenal myelolipoma', "amyand's hernia", 'amyloidosis', 'aneurysm, cerebral', 'aneurysmal bone cyst', 'angiomyolipoma', 'ankylosing spondylitis', 'anterior mediastinal mass differential diagnosis', 'aortic coarctation', 'aortic dissection', 'aortic dissection, aortic tear', 'aortic nipple', 'aortic pseudoaneurysm', 'appendiceal rupture', 'appendicitis', 'aspergillosis and the air-crescent sign', 'atelectasis', 'atlantoaxial instability', 'atrial septal defect', 'autosomal dominant polycystic kidney disease', 'autosomal recessive polycystic kidney disease', 'avascular necrosis', 'avascular necrosis of the femoral head', 'azygous lobe', 'basic chest imaging review, search pattern, required structures', 'benign cystic teratoma', 'bicornuate uterus', 'bilateral locked facets', 'bilateral perched facets c5 c6 with spinal cord injury', 'biliary leak, status post laparoscopic cholecystectomy', 'breast implant, \xa0rupture, extracapsular silicone', 'bronchial carcinoid', 'bronchiectasis', 'bronchogenic carcinoma', 'bucket handle meniscal tear of the knee', 'c-spine fracture', 'calcific tendinitis', 'capillary hemangioma', 'carcinoma, small cell', 'carotid artery dissection', 'caudal regression syndrome', 'cavernous hemangioma', 'cecal volvulus', 'cervical spine fracture (unstable) with cord injury', 'chance-type fracture', 'chiari i with cervical spine syrinx.', 'chloroma', 'choledocholithiasis', 'cholelithiasis', 'chondrocalcinosis', 'cirrhosis of the liver', 'classic bosniak class iii complex renal cyst', 'classical hodgkins lymphoma, nodular sclerosis subtype', 'clear cell chondrosarcoma', 'clear cell sarcoma of the kidney', 'coarctation of the aorta', 'colon cancer', 'comminuted fracture of medial femoral condyle. small joint effusion.', 'common carotid occlusion, collateral reconstitution of ipsilateral ica from vertebral artery muscular branches', 'congenital carpal fusion', 'congenital cystic adenomatoid malformation', 'cord infarct with secondary atrophy', 'crohn disease', "crohn's disease", 'crossed fused ectopia', 'ct evaluation of acute cholecystitis', 'cystic fibrosis', 'deep venous thrombosis', 'dermoid cyst', 'dermoid cyst (cystic teratoma)', 'diastematomyelia', 'diffuse idiopathic skeletal hyperostosis (dish), cervical and thoracic spine fractures', 'diffuse large b-cell lymphoma', 'diffuse rhabdomyosarcoma', 'diverticulitis', 'double aortic arch', 'duodenal diverticulum', 'duplex kidney with ectopic ureterocele', 'duplicated inferior vena cava', 'duplicated renal collecting system', 'dural \xa0fistula, avf', 'ectopic pregnancy', 'empyema', 'enchondroma', 'endograft leak', 'endometrial polyp', 'endometrioma', 'enlarged subarachnoid space', 'ependymoma cervical spinal cord', 'epididymitis', 'epidural spinal hematoma', 'epiploic appendagitis', 'erosive osteoarthritis', 'esophageal foreign body - coin ingestion', 'ewing sarcoma', "ewing's sarcoma", 'extramedullary hematopoiesis', 'fat necrosis', 'femoral neck stress fractures', 'fibromatosis coli', 'fibrous dysplasia', 'focal nodular hyperplasia', 'foregut cyst', 'foreign body aspiration', 'fractures of the base of the fifth metatarsal', 'ganglioneuroma', 'germinal matrix hemorrhage', 'giant cell tumor', 'granular cell tumor', 'hemangioma, soft-tissue', 'hemiazygous and azygous continuation of the inferior vena cava', 'hemophilia', 'hepatic adenoma', 'hepatic hemangioma', 'hepatoblastoma', 'hepatocellular carcinoma and bone metastasis.', 'hereditary hemorrhagic  ...
# len 332
# train19_df (2162, 4)
# val19_df (322, 4)
# test19_df (99, 5)
# self.train_df (6583, 4)
# answer_freq {'no': 862, 'yes': 758, 'pulmonary embolism': 96, 'acute appendicitis': 86, 'adenocarcinoma of the lung': 54, 'meningioma': 53, 'sarcoidosis': 52, 'angiomyolipoma': 51, 'osteochondroma': 45, 'ankylosing spondylitis': 42, 'neuroblastoma': 42, 'osteomyelitis': 39, 'achalasia': 39, 'hiatal hernia': 39, 'renal cell carcinoma': 39, 'partial anomalous pulmonary venous return': 39, 'diverticulitis': 38, 'horseshoe kidney': 37, 'spine, epidural abscess': 36, 'epidural spinal hematoma': 36, 'ectopic pregnancy': 35, 'left aortic arch with aberrant right subclavian artery': 34, 'double aortic arch': 33, 'pancreatic adenocarcinoma': 32, 'synovial cyst': 32, 'colon cancer': 29, "crohn's disease": 28, 'hypertrophic pyloric stenosis': 28, 'fibrous dysplasia': 28, 'enchondroma': 28, 'pericardial cyst': 28, "hodgkin's lymphoma": 27, 'schwannoma': 27, 'c-spine fracture': 27, 'dural \xa0fistula, avf': 27, 'osteoid osteoma': 26, 'intraosseous lipoma': 25, 'intussusception': 25, 'diastematomyelia': 25, 'pulmonary sequestration': 24, 'rheumatoid arthritis': 24, 'femoral neck stress fractures': 24, 'tibial plateau fracture': 24, 'mature cystic teratoma': 23, 'langerhan cell histiocytosis': 23, 'coarctation of the aorta': 23, 'rickets': 22, 'appendicitis': 22, 'spinal cord astrocytoma': 22, 'enlarged subarachnoid space': 22, 'pulmonary sarcoidosis': 22, 'epiploic appendagitis': 22, 'avascular necrosis': 21, 'ruptured appendicitis': 21, 'duplicated inferior vena cava': 21, 'ewing sarcoma': 21, 'liver hemangioma': 20, 'pulmonary arteriovenous malformation': 20, 'osteogenesis imperfecta': 20, 'tophaceous gout': 20, 'empyema': 20, 'aneurysmal bone cyst': 20, 'nonossifying fibroma': 19, 'pneumomediastinum': 19, 'iatrogenic pneumoperitoneum': 19, 'parathyroid adenoma': 19, 'intralobar pulmonary sequestration': 19, 'multiple myeloma': 19, 'pheochromocytoma': 19, 'right aortic arch with aberrant left subclavian artery': 19, 'medullary nephrocalcinosis': 19, 'infiltrating ductal carcinoma': 18, 'autosomal recessive polycystic kidney disease': 18, 'lung adenocarcinoma and cns metastasis': 18, 'leptomeningeal sarcoid': 18, 'pseudomembranous colitis': 18, 'lipomatous hypertrophy of the interatrial septum': 18, 'pleomorphic \xa0xanthoastrocytoma, pxa': 18, 'carotid artery dissection': 18, 'aortic dissection, aortic tear': 18, 'wilms tumor': 18, 'endometrial polyp': 18, 'abdominal aortic aneurysm': 18, 'crohn disease': 18, 'aberrant right subclavian artery (arsa)': 17, 'osteochondritis dissecans': 17, 'multiple osteochondromatosis': 17, 'hepatic hemangioma': 17, 'adenomyosis': 17, "ewing's sarcoma": 17, 'transitional cell carcinoma, bladder': 17, 'congenital cystic adenomatoid malformation': 17, 'duplicated renal collecting system': 16, 'aortic dissection': 16, 'varicocele': 16, 'aneurysm, cerebral': 16, "zenker's diverticulum": 16, 'radial head fracture': 16, 'pulmonary thromboembolism': 16, 'traumatic transient lateral patellar dislocation.': 16, 'adpkd -autosomal dominant polycystic kidney disease': 16, 'scaphoid fracture': 16, 'occult stress fracture': 16, 'pneumonia': 16, 'adrenal myelolipoma': 15, 'fractures of the base of the fifth metatarsal': 15, 'osteosarcoma': 15, 'focal nodular hyperplasia': 15, 'crossed fused ectopia': 15, 'supracondylar fracture': 15, 'cholelithiasis': 15, 'endometrioma': 15, 'hepatic adenoma': 15, 'amyloidosis': 15, 'extramedullary hematopoiesis': 15, 'stress fracture': 15, 'benign cystic teratoma': 15, 'segmental omental infarct': 14, 'dermoid cyst': 14, 'adrenal adenoma': 14, 'azygous lobe': 14, 'neurofibromatosis-1, nf1, nf-1': 14, 'testicular microlithiasis': 14, 'cavernous hemangioma': 14, 'multiple hereditary exostosis': 14, 'diffuse large b-cell lymphoma': 14, 'small bowel lymphoma': 14, 'aspergillosis and the air-crescent sign': 14, 'sickle cell anemia': 14, 'cystic fibrosis': 14, 'acute mesenteric ischemia': 14, 'mycotic aneurysm': 14, 'myelolipoma': 14, 'portal vein thrombosis': 14, 'hydropneumothorax': 14, 'pn ...
# threshold 1
# self.val_df (500, 5)
# self.test_df (500, 4)

# %%
dm.check()
# Out:
# Data augmentation:
# 	Compose(
#     Resize(size=(232, 232), interpolation=bilinear, max_size=None, antialias=warn)
#     RandomCrop(size=(224, 224), padding=None)
#     RandomHorizontalFlip(p=0.5)
#     ToTensor()
#     Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
# )
# 	Compose(
#     Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=warn)
#     ToTensor()
#     Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
# )
# # training samples = (6583, 5)
# # validation samples = (500, 5)
# saved
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 dm.check()
#
# Cell In[142], line 205, in PrepareCLEF2020DataWithQ.check(self)
#     203 print('saved')
#     204 if self.n_classes == 330:
# --> 205     assert self.train_df.shape == (4963, 5)
#     206     assert self.val_df.shape == (472, 5)
#     207 elif self.n_classes == 332:
#
# AssertionError:

# %%
class PrepareCLEF2019DataWithQ:
    def __init__(self, CNF) -> None:
        self.n_classes = CNF.data.n_classes
        self.QG = CNF.data.QG

        # TRAINING DATA
        # This is the main dataset for training
        train19_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_19_train_qa,
            imgs_path=CNF.paths.clef_19_train_imgs,
            is_main_df=True
        )
        
        print('train19_df',train19_df.shape)
        print('unique',len(train19_df.A.unique().tolist()))
        answer_freq = self._count_answer_freq(train19_df)
        print('answer_freq',answer_freq)
        self.classes_dict = self._get_most_frequent_classes(answer_freq, 5)
        # Get categorical abnormality classes
        # self.classes = train20_df.A.unique().tolist()
        self.classes = list(self.classes_dict.keys())
        print('len classes',len(self.classes))
        # if self.n_classes == 330:
        #     if 'no' in self.classes:
        #         self.classes.remove('no')
        #     if 'yes' in self.classes:
        #         self.classes.remove('yes')
        self.classes = sorted(self.classes)
        print('classes',self.classes)
        print('len',len(self.classes))
        # assert len(self.classes) == self.n_classes
        # Remove yes/no classes from train20_df
        # train20_df = pd.DataFrame([
        #     row for row in train20_df.itertuples() if row.A in self.classes
        # ]).drop("Index", axis=1)

        
        # Filter abnormality data from other ImageCLEF datasets
        # print(type(train20_df))
        # display(train20_df)
        train20_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_20_train_qa,
            imgs_path=CNF.paths.clef_20_train_imgs
        )
        val20_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_20_val_qa,
            imgs_path=CNF.paths.clef_20_val_imgs
        )
        print('train20_df',train20_df.shape)
        print('val20_df',val20_df.shape)

        # test19_df = self._make_dataframe(
        #     columns=CNF.clef_cols.test19,
        #     qa_path=CNF.paths.clef_19_test_qa,
        #     imgs_path=CNF.paths.clef_19_test_imgs
        # )
        # print(test19_df.shape)
        # display(test19_df)
        # print('test19_df',test19_df)
        
        # test19_df = test19_df.drop('Task', axis=1)
        test20_df = self._make_dataframe(
            columns=CNF.clef_cols.test20A,
            qa_path=CNF.paths.clef_20_test_qa_sysu,
            imgs_path=CNF.paths.clef_20_test_imgs
        )
        print('test20_df',test20_df.shape)

        val21_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_21_val_qa,
            imgs_path=CNF.paths.clef_21_val_imgs
        )
        print('val21_df',val21_df.shape)
        training_dfs = [train19_df, val20_df, val21_df, test20_df, train20_df]
        self.train_df = pd.concat(
            training_dfs, ignore_index=True
        ).reset_index(drop=True)

        # answer_freq = self._count_answer_freq(self.train_df)
        # print('answer_freq',answer_freq)
        # self.classes = self._get_most_frequent_classes(answer_freq, 1)
        self.train_df['labels'] = self.train_df['A'].apply(lambda x : self.classes_dict[x] if x in self.classes_dict else self.classes_dict['UNKNOWN'])

        self.val_df = self._make_dataframe(
            columns=CNF.clef_cols.default,
            qa_path=CNF.paths.clef_19_val_qa,
            imgs_path=CNF.paths.clef_19_val_imgs,
            is_main_df=True
        )

        self.val_df['labels'] = self.val_df['A'].apply(lambda x : self.classes_dict[x] if x in self.classes_dict else self.classes_dict['UNKNOWN'])
        print('self.val_df',self.val_df.shape)

        self.test19_df = self._make_dataframe(
            columns=CNF.clef_cols.test19,
            qa_path=CNF.paths.clef_19_test_qa,
            imgs_path=CNF.paths.clef_19_test_imgs,
            is_main_df=True
        )
        print('test19_df',self.test19_df.shape)

        # Augmentation
        self.train_tfms = T.Compose([
            T.Resize(size=(CNF.model.inp_size + 8, CNF.model.inp_size + 8)),
            # T.AutoAugment(),
            T.RandomCrop(size=(CNF.model.inp_size, CNF.model.inp_size)),
            T.RandomHorizontalFlip(),
            T.ToTensor(),
            T.Normalize(
                mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
            )
        ])
        self.val_tfms = T.Compose([
            T.Resize(size=(CNF.model.inp_size, CNF.model.inp_size)),
            T.ToTensor(),
            T.Normalize(
                mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
            )
        ])
        # Generate new questions for training dataset
        if CNF.data.QG:
            print(f"Before QG: # training samples = {self.train_df.shape[0]}")
            self.train_df = self._generate_questions(self.train_df,
                                                     CNF.task_keywords)
            print(f"After QG: # training samples = {self.train_df.shape[0]}")
        self.tokenizer = Tokenizer.from_list(
            self.train_df.Q.unique().tolist(),
            max_len=CNF.model.max_len
        )
        # Make dataset classes
        self.trainset = VQADataset(
            self.train_df, self.train_tfms, self.classes, self.tokenizer
        )
        self.valset = VQADataset(
            self.val_df, self.val_tfms, self.classes, self.tokenizer
        )
        # Make dataloaders
        self.dls = DataLoaders.from_dataset(
            trainset=self.trainset,
            train_bs=CNF.train.bs,
            valset=self.valset,
            val_bs=1,
            collate_fn=vqa_collate_fn
        )

    def _make_dataframe(self,
                        columns,
                        qa_path,
                        imgs_path,
                        is_main_df=False):
        df = load_qa_file(qa_filepath=qa_path, columns=columns)
        df['PATH'] = df.ID.apply(lambda x: f"{imgs_path}/{x}.jpg")
        if not is_main_df:
            df = pd.DataFrame([
                row for row in df.itertuples() if row.A in self.classes
            ]).drop("Index", axis=1)
        return df
    
    def _count_answer_freq(self,train_df: pd.DataFrame):
        '''
        count the frequence of each unique answer on the dataset
        '''
        all_answers = train_df['A'].values
        answer_freq_dict = defaultdict(int)
        for answer in all_answers:
            answer_freq_dict[answer] += 1
        answer_freq_dict_sort = dict(sorted(answer_freq_dict.items(), key=lambda x: x[1], reverse=True))

        return answer_freq_dict_sort
    
    def _get_most_frequent_classes(self,answer_freq_dict, threshold=1):
        print('threshold',threshold)
        final_classes = defaultdict(int)
        index = 0

        for answer,ans_freq in answer_freq_dict.items():

            if ans_freq >= threshold:
                final_classes[answer]= index         
            else:
                final_classes['UNKNOWN'] = index
                break
            index += 1  
        final_classes['UNKNOWN'] = index
        with open('answer_classes.json', 'w') as fp:
            json.dump(final_classes, fp)
        return final_classes

    # def _generate_questions(
    #     self,
    #     train_df: pd.DataFrame,
    #     task_keywords: Dict[str, List[str]]
    # ) -> pd.DataFrame:
    #     new_train_df = generate_new_questions_dataframe(
    #         train_df, task_keywords
    #     )
    #     new_train_df = new_train_df[new_train_df.Task == 'abnormality']
    #     new_train_df = new_train_df[new_train_df.SubTask == 'categorical']
    #     return new_train_df

    def check(self):
        print(f"Data augmentation:\n\t{self.train_tfms}", end='')
        print(f"\n\t{self.val_tfms}")
        print(f"# training samples = {self.train_df.shape}")
        print(f"# validation samples = {self.val_df.shape}")
        train_pickle_name='train19_subset20_21_df'
        self.train_df.to_pickle('/home/anurag/Med_VQA/train_dataset_pickle/'+train_pickle_name+'.pkl')
        valid_pickle_name = 'val19_df'
        self.val_df.to_pickle('/home/anurag/Med_VQA/valid_dataset_pickle/'+valid_pickle_name+'.pkl')
        test_pickle_name = 'test19_df'
        self.test19_df.to_pickle('/home/anurag/Med_VQA/test_dataset_pickle/'+test_pickle_name+'.pkl')
        if self.n_classes == 330:
            assert self.train_df.shape == (4963, 5)
            assert self.val_df.shape == (472, 5)
        elif self.n_classes == 332:
            if self.QG:
                assert self.train_df.shape == (39704, 6)
            else:
                assert self.train_df.shape == (6583, 4)
            assert self.val_df.shape == (500, 4)
        else:
            _errmsg = f"check not added for classes = {self.n_classes}"
            raise NotImplementedError(_errmsg)
        assert self.train_df.A.nunique() <= self.n_classes
        assert self.val_df.A.nunique() <= self.n_classes
        assert len(self.trainset) == self.train_df.shape[0]
        assert len(self.valset) == self.val_df.shape[0]

        batch = next(iter(self.dls.trainloader))
        print(f"data batch:")
        print(f"\tV = {batch['inputs']['V'].shape}")
        print(f"\tQ = {batch['inputs']['Q']['input_ids'].shape}")
        print(f"\tA = {batch['target'].shape}")
        print("data check: [green]PASSED[/green]")

# %%
dm = PrepareCLEF2019DataWithQ(CNF)
# Out:
# train19_df (12792, 4)
# unique 1552
# answer_freq {'axial': 1558, 'skull and contents': 1216, 'no': 679, 'yes': 615, 'sagittal': 478, 'xr - plain film': 456, 'musculoskeletal': 436, 'coronal': 389, 'gastrointestinal': 352, 'lung, mediastinum, pleura': 250, 'spine and contents': 234, 'genitourinary': 214, 't2': 205, 'ap': 197, 'face, sinuses, and neck': 191, 'us - ultrasound': 183, 'lateral': 151, 't1': 131, 'vascular and lymphatic': 122, 'frontal': 120, 'heart and great vessels': 120, 'noncontrast': 100, 'pa': 92, 'contrast': 87, 'mr - flair': 78, 'an - angiogram': 78, 'transverse': 76, 'ct noncontrast': 71, 'breast': 65, 'flair': 58, 'oblique': 50, 'mr - t2 weighted': 47, 'cta - ct angiography': 45, 'ct with iv contrast': 45, 'longitudinal': 43, 'iv': 42, 'ct w/contrast (iv)': 38, 'mr - t1w - noncontrast': 32, 'mr - dwi diffusion weighted': 30, 'meningioma': 30, 'mr - t1w w/gadolinium': 29, 'glioblastoma multiforme': 28, 'mammograph': 24, 'mra - mr angiography/venography': 24, 'bas - barium swallow': 23, 'mr - other pulse seq.': 22, '3d reconstruction': 22, 'nm - nuclear medicine': 18, 'mr - pdw proton density': 18, 'mr - adc map (app diff coeff)': 16, 'pulmonary embolism': 16, 'ugi - upper gi': 14, 'arteriovenous malformation (avm)': 14, 'acute appendicitis': 14, 'ct with gi and iv contrast': 13, 'us-d - doppler ultrasound': 13, 'arachnoid cyst': 13, 'schwannoma': 13, 'tuberous sclerosis': 13, 'gi and iv': 12, 'ependymoma': 12, 'fibrous dysplasia': 12, 'multiple sclerosis': 12, 'brain, cerebral abscess': 12, 'ct - gi & iv contrast': 11, 'mammo - cc': 11, 'sarcoidosis': 11, 'diverticulitis': 11, 'langerhan cell histiocytosis': 11, 'be - barium enema': 10, 'acute disseminated encephalomyelitis (adem)': 10, 'adenocarcinoma of the lung': 10, 'diffuse large b-cell lymphoma': 10, 'aneurysm, cerebral': 10, 'cerebellar hemangioblastoma': 10, 'avm, arterio-venous malformation, vascular malformation': 10, 'mammo - mlo': 9, 'brain abscess, central nervous system': 9, 'craniopharyngioma': 9, 'leptomeningeal carcinomatosis': 9, 'cerebral infarction (stroke)': 9, 'odontoid process fracture, type ii': 9, 'acute disseminated encephalomyelitis': 9, 'ankylosing spondylitis': 8, 'dermoid cyst': 8, 'astrocytoma, grading and subtypes': 8, 'osteomyelitis': 8, 'rickets': 8, 'dnet (dysembryoplastic neuroepithelial tumor)': 8, 'intracranial lipoma': 8, 'medulloblastoma': 8, 'intraventricular meningioma': 8, 'juvenile pilocytic astrocytoma': 8, 'astrocytoma, low-grade (who 2), supratentorial': 8, 'posterior reversible encephalopathy syndrome (pres)': 8, 'mr - t1w w/gd (fat suppressed)': 7, 'sbft - small bowel': 7, 'atypical teratoid/rhabdoid tumor': 7, 'dural sinus thrombosis': 7, 'pancreatic adenocarcinoma': 7, 'pilomyxoid astrocytoma (pma), who grade 2': 7, 'epidermoid cyst': 7, 'intracranial hypotension': 7, 'synovial cyst': 7, 'colloid (neuroepithelial) cyst of the third ventricle': 7, 'neuroblastoma': 7, 'anoxic brain injury, anoxia': 7, 'dural \xa0fistula, avf': 7, 'mr t2* gradient,gre,mpgr,swan,swi': 6, 'hyperdense middle cerebral artery sign': 6, 'esophageal b-cell lymphoma': 6, 'spine, epidural abscess': 6, 'cerebral infarction': 6, 'osteoid osteoma': 6, 'liver hemangioma': 6, 'epidural spinal hematoma': 6, 'vestibular schwannoma': 6, 'adult medulloblastoma': 6, 'neurosarcoid, cns sarcoid': 6, 'hypertrophic pyloric stenosis': 6, 'blowout fracture of orbit': 6, 'malignant peripheral nerve sheath tumor (mpnst)': 6, 'pilocytic astrocytoma': 6, 'multiple hereditary exostosis': 6, 'left aortic arch with aberrant right subclavian artery': 6, 'brain abscess (gram positive cocci)': 6, 'lipomatous hypertrophy of the interatrial septum': 6, 'choroid plexus neoplasm, papilloma, carcinoma': 6, 'tophaceous gout': 6, 'pituitary apoplexy': 6, 'chondrosarcoma': 6, 'langerhans cell histiocytosis': 6, 'torch infections': 6, 'rheumatoid arthritis': 6, 'vertebral artery dissection with cerebellar infarction': 6, 'papillary glioneuronal tumor': 6, 'enchondroma': 6, 'gallbladder polyp': 6, 'oropharyn ...
# threshold 5
# len classes 178
# classes ['3d reconstruction', 'UNKNOWN', 'achalasia', 'acute appendicitis', 'acute disseminated encephalomyelitis', 'acute disseminated encephalomyelitis (adem)', 'acute myelogenous leukemia, aml', 'adenocarcinoma of the lung', 'adpkd -autosomal dominant polycystic kidney disease', 'adult medulloblastoma', 'agenesis of the corpus callosum', 'an - angiogram', 'aneurysm, cerebral', 'angiomyolipoma', 'ankylosing spondylitis', 'anoxic brain injury, anoxia', 'ap', 'arachnoid cyst', 'arteriovenous malformation', 'arteriovenous malformation (avm)', 'astrocytoma, grading and subtypes', 'astrocytoma, low-grade (who 2), supratentorial', 'atypical teratoid/rhabdoid tumor', 'avascular necrosis', 'avm, arterio-venous malformation, vascular malformation', 'axial', 'bas - barium swallow', 'be - barium enema', 'blowout fracture of orbit', 'brain abscess (gram positive cocci)', 'brain abscess, central nervous system', 'brain, cerebral abscess', 'breast', 'carotid artery dissection', 'central neurocytoma', 'cerebellar hemangioblastoma', 'cerebral infarction', 'cerebral infarction (stroke)', 'childhood brain tumors, epidemiology, demographics', 'chondrosarcoma', 'choroid plexus neoplasm, papilloma, carcinoma', 'choroid plexus papilloma', 'colloid (neuroepithelial) cyst of the third ventricle', 'contrast', 'coronal', 'craniopharyngioma', 'crossed fused ectopia', 'ct - gi & iv contrast', 'ct noncontrast', 'ct w/contrast (iv)', 'ct with gi and iv contrast', 'ct with iv contrast', 'cta - ct angiography', 'dermoid cyst', 'diastematomyelia', 'diffuse large b-cell lymphoma', 'diverticulitis', 'dnet (dysembryoplastic neuroepithelial tumor)', 'duplicated inferior vena cava', 'duplicated renal collecting system', 'dural sinus thrombosis', 'dural \xa0fistula, avf', 'ectopic pregnancy', 'emphysematous cholecystitis', 'enchondroma', 'ependymal neoplasms, ependymoma', 'ependymoma', 'epidermoid cyst', 'epidural spinal hematoma', 'esophageal b-cell lymphoma', 'face, sinuses, and neck', 'fibrous dysplasia', 'flair', 'frontal', 'fronto-nasal encephalocele', 'gallbladder polyp', 'gastrointestinal', 'genitourinary', 'gi and iv', 'glioblastoma multiforme', 'heart and great vessels', "hodgkin's lymphoma", 'hyperdense middle cerebral artery sign', 'hypertrophic pyloric stenosis', 'hypoxic/ischemic encephalopathy', 'intracranial hypotension', 'intracranial lipoma', 'intracranial venous thrombosis', 'intravascular lymphomatosis', 'intraventricular meningioma', 'invasive lobular carcinoma', 'iv', 'juvenile pilocytic astrocytoma', 'langerhan cell histiocytosis', 'langerhans cell histiocytosis', 'lateral', 'left aortic arch with aberrant right subclavian artery', 'leptomeningeal carcinomatosis', 'lipomatous hypertrophy of the interatrial septum', 'liver hemangioma', 'lobar holoprosencephaly', 'longitudinal', 'lung, mediastinum, pleura', 'malignant peripheral nerve sheath tumor (mpnst)', 'mammo - cc', 'mammo - mlo', 'mammograph', 'medulloblastoma', 'meningioma', 'midgut malrotation', 'mr - adc map (app diff coeff)', 'mr - dwi diffusion weighted', 'mr - flair', 'mr - other pulse seq.', 'mr - pdw proton density', 'mr - stir', 'mr - t1w - noncontrast', 'mr - t1w w/gadolinium', 'mr - t1w w/gd (fat suppressed)', 'mr - t2 weighted', 'mr t2* gradient,gre,mpgr,swan,swi', 'mra - mr angiography/venography', 'multiple hereditary exostosis', 'multiple sclerosis', 'musculoskeletal', 'mycotic aneurysm', 'neuroblastoma', 'neurosarcoid, cns sarcoid', 'nm - nuclear medicine', 'no', 'noncontrast', 'nonossifying fibroma', 'oblique', 'odontoid process fracture, type ii', 'orbital retrobulbar dermoid cyst', 'oropharyngeal cancer', 'osteoid osteoma', 'osteomyelitis', 'osteosarcoma', 'pa', 'pancreatic adenocarcinoma', 'papillary glioneuronal tumor', 'paradoxic embolization, patent foramen ovale, cerebral infarction', 'pilocytic astrocytoma', 'pilomyxoid astrocytoma (pma), who grade 2', 'pituitary apoplexy', 'pituitary macroadenoma', 'posterior reversible encephalopathy syndrome (pres)', 'pulmonar ...
# len 178
# train20_df (1039, 4)
# val20_df (153, 4)
# test20_df (93, 4)
# val21_df (139, 4)
# self.val_df (2000, 5)
# test19_df (500, 5)

# %%
dm.check()
# Out:
# Data augmentation:
# 	Compose(
#     Resize(size=(232, 232), interpolation=bilinear, max_size=None, antialias=warn)
#     RandomCrop(size=(224, 224), padding=None)
#     RandomHorizontalFlip(p=0.5)
#     ToTensor()
#     Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
# )
# 	Compose(
#     Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=warn)
#     ToTensor()
#     Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
# )
# # training samples = (14216, 5)
# # validation samples = (2000, 5)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 dm.check()
#
# Cell In[145], line 217, in PrepareCLEF2019DataWithQ.check(self)
#     215 self.test19_df.to_pickle('/home/anurag/Med_VQA/test_dataset_pickle/'+test_pickle_name+'.pkl')
#     216 if self.n_classes == 330:
# --> 217     assert self.train_df.shape == (4963, 5)
#     218     assert self.val_df.shape == (472, 5)
#     219 elif self.n_classes == 332:
#
# AssertionError:
